# %%
import netCDF4 as nc
import matplotlib.pyplot as plt
import numpy as np
import scipy.io.netcdf as netcdf

# %%
vmec_file = nc.Dataset("wout/wout_tj2curref.nc","r")
#wout_file = netcdf.netcdf_file("wout_files/Eq_NBI.nc", 'r')

# %%
variable_names = vmec_file.variables
# Print information about each variable
for var_name, var in variable_names.items():
    print(f"Variable: {var_name}")
# Out:
# Variable: version_
# Variable: input_extension
# Variable: mgrid_file
# Variable: pcurr_type
# Variable: pmass_type
# Variable: piota_type
# Variable: wb
# Variable: wp
# Variable: gamma
# Variable: rmax_surf
# Variable: rmin_surf
# Variable: zmax_surf
# Variable: nfp
# Variable: ns
# Variable: mpol
# Variable: ntor
# Variable: mnmax
# Variable: mnmax_nyq
# Variable: niter
# Variable: itfsq
# Variable: lasym__logical__
# Variable: lrecon__logical__
# Variable: lfreeb__logical__
# Variable: lrfp__logical__
# Variable: ier_flag
# Variable: aspect
# Variable: betatotal
# Variable: betapol
# Variable: betator
# Variable: betaxis
# Variable: b0
# Variable: rbtor0
# Variable: rbtor
# Variable: signgs
# Variable: IonLarmor
# Variable: volavgB
# Variable: ctor
# Variable: Aminor_p
# Variable: Rmajor_p
# Variable: volume_p
# Variable: ftolv
# Variable: fsql
# Variable: fsqr
# Variable: fsqz
# Variable: nextcur
# Variable: extcur
# Variable: mgrid_mode
# Variable: xm
# Variable: xn
# ...

# %%
ionLarmor = vmec_file.variables["iotaf"]
#iota = vmec_file.variables["iota_b"]
ionLarmor = ionLarmor[:]

# %%
psi = vmec_file.variables["phi"]
iota = vmec_file.variables["iotaf"]

# %%
r = np.linspace(0,1,len(iota))
r = np.sqrt(r)
# %matplotlib notebook
plt.plot(r,abs(ionLarmor))
#plt.colorbar()
plt.title('Iota Profile')
plt.xlabel('r/a')
plt.ylabel('')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
